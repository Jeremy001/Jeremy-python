# %% [markdown]
# # Seaborn Tutorial
# ***
#
# - 1.Controlling figure aesthetics
# - 2.Choosing color palettes
# - 3.Visualizing the distribution of a dataset
# - 4.Plotting with categorical data
# - 5.Visualizing linear relationships

# %% [markdown]
# ## 1. Controlling figure aesthetics
# ***

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(sum(map(ord, 'aesthetics')))

# %%
# define a simple function to plot some offset sine waves
def sinplot(flip = 1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
# plot
sinplot()

# %%
#  switch to seaborn defaults, simply call the set() function.
sns.set()
sinplot()

# %%
# There are five preset seaborn themes: darkgrid, whitegrid, dark, white, and ticks
# The default theme is darkgrid. 
sns.set_style('darkgrid')
sinplot()

# %%
sns.set_style('whitegrid')
sinplot()

# %%
sns.set_style('dark')
sinplot()

# %%
sns.set_style('white')
sinplot()

# %%
# 有横纵坐标刻度线
sns.set_style('ticks')
sinplot()

# %%
sns.set_style('whitegrid')
data = np.random.normal(size = (20, 6)) + np.arange(6) / 2
sns.boxplot(data = data)

# %%
# 去掉顶部和右侧的边框
# 只有theme = white or ticks才可以去掉
sns.set_style('ticks')
sinplot()
sns.despine()

# %%
# offsetting the spines 
f, ax = plt.subplots()
sns.violinplot(data = data)
sns.despine(offset = 10, trim = True)

# %%
# define which spines are removed
sns.set_style('whitegrid')
sns.boxplot(data = data, palette='deep')
sns.despine(left = True)

# %%
# 为某个图形单独设置样式 with
# in a with statement to temporarily set plot parameters
with sns.axes_style('whitegrid'):
    plt.subplot(221)
    sinplot()
with sns.axes_style('darkgrid'):
    plt.subplot(222)
    sinplot()
plt.subplot(223)
sinplot()
plt.subplot(224)
sinplot()
# plt.subplot(ABC):A行数 B列数 C第几个子图，第一行从左往右数

# %%
# elements of the seaborn styles
sns.axes_style()
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': '.8',
#  'axes.facecolor': 'white',
#  'axes.grid': True,
#  'axes.labelcolor': '.15',
#  'axes.linewidth': 1.0,
#  'figure.facecolor': 'white',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'image.cmap': 'rocket',
#  'legend.frameon': False,
#  'legend.numpoints': 1,
#  'legend.scatterpoints': 1,
#  'lines.solid_capstyle': 'round',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'xtick.direction': 'out',
#  'xtick.major.size': 0.0,
#  'xtick.minor.size': 0.0,
#  'ytick.color': '.15',
#  'ytick.direction': 'out',
#  'ytick.major.size': 0.0,
#  'ytick.minor.size': 0.0}

# %%
# 设置以上的参数
sns.set_style('darkgrid', {"axis.facecolor":"0.9"})
sinplot()

# %%
# 重置设置
sns.set()

# %%
# The four preset contexts, in order of relative size, are paper, notebook, talk, and poster. The notebook style is the default
sns.set_context('paper')
sinplot()

# %%
sns.set_context('talk')
sinplot()

# %%
sns.set_context('poster')
sinplot()

# %%
# use set_context() to set
sns.set_context('notebook', font_scale = 1.5, rc = {"lines.linwidth":2.5})
sinplot()

# %%
sinplot()

# %% [markdown]
# ## 2. Choosing color palettes
#
# - color_palette()
# - set_palette()
# - hls_palette()
# - husl_palette()

# %%
sns.set(rc = {'figure.figsize':(20, 14)})
np.random.seed(sum(map(ord, 'palettes')))

# %%
# 当前palette
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %%
# 设置想要展现的颜色类别数
# 默认是6个，当多于6个时，可以自定义颜色数
sns.palplot(sns.color_palette('hls', 10))
# 以上默认的明度和饱和度是0
# 也可以自定义明度和饱和度
sns.palplot(sns.hls_palette(10, l = .3, s = .8))
sns.palplot(sns.hls_palette(10, l = .5, s = .8))

# %%
# 由于人类视觉系统的工作性质，即使同样强度的颜色，我们认为黄和绿更亮而蓝色更暗
# 因此seaborn有另外一套更标准的颜色系统husl, 产生得到的颜色让人看起来亮度是一样的
sns.palplot(sns.color_palette('husl', 10))
sns.palplot(sns.husl_palette(10, l = .5, s = .8))

# %%
# Using categorical Color Brewer palettes
sns.palplot(sns.color_palette('Paired'))

# %%
sns.palplot(sns.color_palette('Set2', 10))

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
sns.palplot(sns.color_palette(flatui))

# %%
# Using named colors from the xkcd color survey
plt.plot([0, 1], [0, 1], sns.xkcd_rgb['pale red'], lw = 3)
plt.plot([0, 1], [0, 2], sns.xkcd_rgb['medium green'], lw = 3)
plt.plot([0, 1], [0, 3], sns.xkcd_rgb['denim blue'], lw = 3)

# %%
colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple"]
sns.palplot(sns.xkcd_palette(colors))

# %%
# Sequential color palettes
sns.palplot(sns.color_palette('Blues'))

# %%
sns.palplot(sns.color_palette('Blues_r'))

# %%
sns.palplot(sns.color_palette('BuGn'))

# %%
sns.palplot(sns.color_palette('BuGn_d'))

# %%
# Sequential “cubehelix” palettes
sns.palplot(sns.color_palette('cubehelix', 8))

# %%
sns.palplot(sns.cubehelix_palette(8))
sns.palplot(sns.cubehelix_palette(8, start = .5, rot = -.75))
sns.palplot(sns.cubehelix_palette(8, start = 2, rot = 0, dark = 0, light = .95, reverse=True))

# %%
x, y = np.random.multivariate_normal([0, 0], [[1, -.5], [-.5, 1]], size = 300).T
cmap = sns.cubehelix_palette(light = 1, as_cmap = True)
sns.kdeplot(x, y, cmap = cmap, shade = True)

# %%
# Custom sequential palettes
sns.palplot(sns.light_palette('green'))

# %%
sns.palplot(sns.dark_palette('green'))

# %%
sns.palplot(sns.light_palette('green',reverse = True))

# %%
pal = sns.light_palette('green', as_cmap=True)
sns.kdeplot(x, y, cmap = pal)

# %%
sns.palplot(sns.light_palette((210, 90, 60), input = 'husl'))

# %%
sns.palplot(sns.light_palette('muted purple', input = 'xkcd'))

# %%
# Diverging color palettes
sns.palplot(sns.color_palette('BrBG', 7))
sns.palplot(sns.color_palette('BrBG_r', 7))
sns.palplot(sns.color_palette('RdBu_r', 7))
sns.palplot(sns.color_palette('coolwarm', 7))

# %%
# Custom diverging palettes
sns.palplot(sns.diverging_palette(220, 20, n = 7))
sns.palplot(sns.diverging_palette(10, 100, n = 7))
sns.palplot(sns.diverging_palette(10, 100, s = 85, l = 25, n = 7))
sns.palplot(sns.diverging_palette(10, 200, sep = 10, n = 7))
sns.palplot(sns.diverging_palette(10, 200, sep = 10, n = 7, center = 'dark'))

# %%
# Setting the default color palette
sns.set_palette('husl')
sinplot()

# %% [markdown]
# ## 3.Visualizing the distribution of a dataset
# ***
# - 3.1 Plotting univariate distributions 单因素
# - 3.2 Plotting bivariate distributions 多因素
# - 3.3 Visualizing pairwise relationships in a dataset

# %% [markdown]
# ### 3.1 Plotting univariate distributions

# %%
# 准备工作：加载所需的类和进行必要的设置
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes = True)
np.random.seed(sum(map(ord, 'distribution')))

# %%
# 绘制直方图的最快捷方式：distplot()
## 默认显示核密度曲线
x = np.random.normal(size = 100)
sns.distplot(x)

# %%
# 去除核密度曲线，显示rug
sns.distplot(x, kde = False, rug = True)

# %%
# 修改bins的数量
## 通过修改bins数量，可以探索该变量的分布
sns.distplot(x, bins = 20, kde = False, rug = True)

# %%
# 核密度估计曲线
sns.distplot(x, hist=False, rug = True)

# %%
# 绘制核密度估计曲线的更快捷方式
sns.kdeplot(x, shade = True)

# %%
# 修改bandwidth
sns.kdeplot(x)
sns.kdeplot(x, bw = .2, label = 'bw:.2')
sns.kdeplot(x, bw = 2, label = 'bw:2')
plt.legend()

# %%
# cut
sns.kdeplot(x, shade = False, cut = 0)
sns.rugplot(x)

# %%
# Fitting parametric distributions
x = np.random.gamma(6, size = 200)
sns.distplot(x, kde = False, fit = stats.gamma)

# %% [markdown]
# ### 3.2 Plotting bivariate distributions

# %%
# 散点图
mean, cov = [0, 1], [(1, .5), (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=['x', 'y'])
sns.jointplot(x = 'x', y = 'y', data = df)

# %%
# 六边形图
x, y = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style('white'):
    sns.jointplot(x = x, y = y, kind = 'hex', color = 'k')

# %%
# 核密度估计曲线
sns.jointplot(x, y, data = df, kind = 'kde')

# %% [markdown]
# ### 3.3 Visualizing pairwise relationships in a dataset

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris, hue = 'species')

# %%
# 更灵活的设置
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, cmap = 'Blues_d', n_levels = 6)
# Out:
# d:\application\python\python36\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ## 4.Plotting with categorical data
# ***

# %% [markdown]
# - 4.1 Categorical scatterplots
# - 4.2 Distributions of observations within categories
# - 4.3 Statistical estimation within categories
# - 4.4 Plotting “wide-form” data
# - 4.5 Drawing multi-panel categorical plots

# %%
# 导入数据集
titanic = sns.load_dataset('titanic')
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### 4.1 Categorical scatterplots

# %% [markdown]
# - stripplot
# - swarmplot

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips)
# stripplot中的点可能会重叠，不太容易看出data的真实分布

# %%
# 给stripplot添加jitter
sns.stripplot(x = 'day', y = 'total_bill', data = tips, jitter = True)

# %%
# 另外一个解决数据点重叠问题的方法是使用swarmplot
sns.swarmplot(x = 'day', y = 'total_bill', data = tips)

# %%
# 可以在swarmplot中添加一个分类变量，区分数据点
# sns.stripplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex', jitter = True)
sns.swarmplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex')

# %%
# 在swarmplot中，X轴分类变量会根据出现顺序进行排序，如果分类变量是数字形式，那么会根据大小排序
sns.swarmplot(x = 'size', y = 'total_bill', data = tips)

# %%
# X轴也可以放置数值型变量，y轴也可以放分类型变量
sns.swarmplot(x = 'total_bill', y = 'day', hue = 'time', data = tips)
# 从周五开始，大家基本都吃晚饭，而周四多数是午饭

# %% [markdown]
# ### 4.2 Distributions of observations within categories

# %% [markdown]
# - boxplot
# - violinplot
# - barplot

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, hue = 'time')

# %%
tips['weekend'] = tips['day'].isin(['Sat', 'Sun'])
sns.boxplot(x = 'day', y = 'total_bill', hue = 'weekend', data = tips, dodge = False)

# %% [markdown]
# - **violinplot 小提琴图**

# %%
# 另一个图形是小提琴图
# 小提琴的两边展示的是数据的分布，这一点比箱线图更直观
sns.violinplot(x = 'day', y = 'total_bill', data = tips)

# %%
# 所以把小提琴倒过来看，也不错
sns.violinplot(x = 'total_bill', y = 'day', data = tips)

# %%
# 添加hue
sns.violinplot(x = 'day', y = 'total_bill', data = tips, hue = 'time')

# %%
# 其他自定义设置
sns.violinplot(x = 'total_bill', y = 'day', hue = 'time', data = tips, bw = .1, scale = 'count', scale_hue = False)

# %%
# 好设置：把小提琴的两边split，用来表示一个二分类变量
sns.violinplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex', split = True)

# %%
# 在小提琴图中还可以显示出数据点
sns.violinplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex', split = True, inner = 'stick', palette = 'Set3')

# %%
# 还可以结合swarmplot和小提琴图（也可以用boxplot）来显示数据点
sns.violinplot(x = 'day', y = 'total_bill', data = tips, inner = None)
sns.swarmplot(x = 'day', y = 'total_bill', data = tips, color = 'w', alpha = .5)

# %% [markdown]
# ### 4.3 Statistical estimation within categories

# %% [markdown]
# - barplot
# - countplot
# - pointplot

# %%
sns.barplot(x = 'sex', y = 'survived', hue = 'class', data = titanic)

# %%
sns.countplot(x = 'deck', data = titanic, palette = 'Greens_d')

# %%
sns.countplot(x = 'sex', hue = 'survived', data = titanic, palette = 'Greens_d')

# %%
sns.countplot(y = 'deck', hue = 'class', data = titanic, palette = 'Greens_d')

# %%
sns.pointplot(x = 'sex', y = 'survived', hue = 'class', data = titanic)

# %%
# 可以设置不同的线型，点型，颜色等
sns.pointplot(x = 'class', y = 'survived', hue = 'sex', data = titanic, 
              palette = {'male':'g', 'female':'m'}, 
              markers = ['^', 'o'], 
              linestyles = ['-', '--'])

# %% [markdown]
# ### 4.4 Plotting “wide-form” data

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# iris是款型数据表，我们如何对iris绘制想要的结果呢？
sns.boxplot(data = iris, orient = 'h')

# %%
sns.boxplot(data = iris, orient = 'v')

# %%
sns.violinplot(x = iris.species, y = iris.sepal_length)

# %%
# 设置图形大小
f, ax = plt.subplots(figsize = (10, 5))
sns.countplot(y = 'deck', data = titanic, color = 'c')

# %% [markdown]
# ### 4.5 Drawing multi-panel categorical plots

# %%
# 用factorplot()来绘制图形
sns.factorplot(x = 'day', y = 'total_bill', hue = 'smoker', data = tips)

# %%
# 通过设置kind参数，来绘制不同类型的图形
sns.factorplot(x = 'day', y = 'total_bill', hue = 'smoker', data = tips, kind = 'bar')

# %%
# 用factorplot()的好处是：很容易分面，通过设置col参数
sns.factorplot(x = 'day', y = 'total_bill', hue = 'smoker', col = 'time', data = tips, kind = 'swarm')

# %%
# 可以设置子图的大小
sns.factorplot(x = 'time', y = 'total_bill', hue = 'smoker', col = 'day', data = tips, 
               kind = 'box', size = 4, aspect = .6)

# %%
# 设置分面， PairGrid
g = sns.PairGrid(tips, 
                 x_vars = ['smoker', 'time', 'sex'], 
                 y_vars = ['total_bill', 'tip'], 
                 aspect = .75, size = 4)
g.map(sns.violinplot, palette = 'pastel')

# %% [markdown]
# ## 5.Visualizing linear relationships
# ***

# %% [markdown]
# ### 5.1 Functions to draw linear regression models

# %%
sns.regplot(x = 'total_bill', y = 'tip', data = tips)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips)

# %%
# lmplot可以用于分类变量
sns.lmplot(x = 'size', y = 'tip', data = tips)

# %%
# 上图中每个size对应的点重叠了，可以jitter开来
sns.lmplot(x = 'size', y = 'tip', data = tips, x_jitter = .1)

# %%
# 还可以估计每个size对应的tip的平均值
sns.lmplot(x = 'size', y = 'tip', data = tips, x_estimator = np.mean)

# %% [markdown]
# ### 5.2 Fitting different kinds of models

# %%
anscombe = sns.load_dataset('anscombe')

# %%
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
anscombe.shape
# Out:
# (44, 3)
