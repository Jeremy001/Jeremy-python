# %%
# 加载包
import requests
from bs4 import BeautifulSoup
import csv
import time
import pandas as pd

# %%
# 参数设置
base_url = 'http://www.ochirly.com.cn'
url_mid = 'list-'
url_end = '-40-listedDate%20desc-0-0-0-0-0.shtml'
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 UBrowser/6.1.2107.204 Safari/537.36'}

# %%
# 获取服装各品类名称和URL、近期上市日期和URL、场景名称和URL
# 获取主页
base_page = requests.get(base_url, headers = header)
base_source = BeautifulSoup(base_page.content, 'html.parser', from_encoding = 'gb18030')
# 把结果写入到csv文件中
csv_file = open('ochirly_category.csv', 
                'w', 
                newline = '', 
                encoding = 'utf-8')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['cat1', 'cat2', 'url', 'page_num'])
## 1. 场景购
for level in base_source.find(attrs = {'data-catalogid':'4940'}).find_all('li')[1:]:
    cat1 = '场景'
    cat2 = level.string
    url_a = level.find_all('a')
    for a in url_a:
        url = a.get('href')
        url1 = base_url + url
        page1 = requests.get(url1, headers = hearder)
        source1 = BeautifulSoup(page1.content, 'html.parser', from_encoding = 'gb13030')
        page_num = source1.find('div', class_ = 'f_r_page').find('input').previous_sibling
        # 写入 csv 文件
        csv_writer.writerow([cat1, cat2, url])
## 2. 新品
for level in base_source.find(attrs = {'data-catalogid':'23'}).find_all('li')[1:6]:
    cat1 = '新品'
    cat2 = level.string
    url_a = level.find_all('a')
    for a in url_a:
        url = a.get('href')
        # 写入 csv 文件
        csv_writer.writerow([cat1, cat2, url])
## 3. 服装
for level in base_source.find(attrs = {'data-catalogid':'3'}).find_all('li')[1:]:
    cat1 = '服装'
    cat2 = level.string
    url_a = level.find_all('a')
    for a in url_a:
        url = a.get('href')
        # 写入 csv 文件
        csv_writer.writerow([cat1, cat2, url])        
# 关闭 csv 文件
csv_file.close()
# Out:
# 服装
# 连衣裙
# /Clothing/Dresses/list.shtml
# 服装
# 毛织
# /Clothing/Sweaters/list.shtml
# 服装
# T恤
# /Clothing/T_Shirts/list.shtml
# 服装
# 衬衫
# /Clothing/Shirts/list.shtml
# 服装
# 半截裙
# /Clothing/Skirts/list.shtml
# 服装
# 裤装
# /Clothing/Pants/list.shtml
# 服装
# 外套
# /Clothing/Jakets/list.shtml
# 服装
# 呢料外套
# /Clothing/Worsted_Coats/list.shtml

# %%
# 读取商品分类信息:ochirly_category.csv
ochirly_category = pd.read_table('./ochirly_category.csv', 
                                 sep = ',', 
                                 encoding = 'utf-8')
ochirly_category
# Out:
#    cat1       cat2                                 url
# 0    场景         休闲      /Scene/Scene_Casual/list.shtml
# 1    场景         工作        /Scene/Scene_Work/list.shtml
# 2    场景       逛街约会        /Scene/Scene_Date/list.shtml
# 3    场景         度假     /Scene/Scene_Holiday/list.shtml
# 4    场景         派对       /Scene/Scene_Party/list.shtml
# 5    场景  SNOOPY限量版      /Scene/Scene_Snoopy/list.shtml
# 6    新品    9月12日到店      /New_In/New_in_9_12/list.shtml
# 7    新品     9月5日到店       /New_In/New_in_9_5/list.shtml
# 8    新品    8月29日到店      /New_In/New_in_8_29/list.shtml
# 9    新品    8月22日到店      /New_In/New_in_8_22/list.shtml
# 10   新品    8月15日到店      /New_In/New_in_8_15/list.shtml
# 11   服装        连衣裙        /Clothing/Dresses/list.shtml
# 12   服装         毛织       /Clothing/Sweaters/list.shtml
# 13   服装         T恤       /Clothing/T_Shirts/list.shtml
# 14   服装         衬衫         /Clothing/Shirts/list.shtml
# 15   服装        半截裙         /Clothing/Skirts/list.shtml
# 16   服装         裤装          /Clothing/Pants/list.shtml
# 17   服装         外套         /Clothing/Jakets/list.shtml
# 18   服装       呢料外套  /Clothing/Worsted_Coats/list.shtml

# %%
# 爬取商品的场景分类
