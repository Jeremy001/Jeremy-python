# %%
# 加载包
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv
import time
import datetime

# %%
# 参数设置
## 增加重连次数
requests.adapters.DEFAULT_RETRIES = 5
base_url = 'http://www.trendiano.com/'
url_end0 = 'list.shtml'
url_end1 = 'list-'
url_end2 = '-30-listedDate%20desc-0-0-0-0-0.shtml'
url_end3 = '-30-catalog%20desc-0-0-0-0-0.shtml'
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 UBrowser/6.1.2107.204 Safari/537.36',
          'Connection':'close'}

# %%
# 类目名称、URL、页码
cat_list = pd.read_table('./trendiano_cat_list.csv', sep = ',', encoding = 'gbk')
cat_list
# Out:
#   cat1_name cat2_name                        cat2_href  page_num
# 0     T恤/衬衫      长袖衬衫   /T_shirts/Long_sleeved_shirts/         2
# 1     T恤/衬衫      短袖衬衫  /T_shirts/Short_sleeved_shirts/         1

# %%
# 爬取商品信息和图片
print('开始')
## 打开 csv 文件，encoding = 'utf-8-sig'，保证写入中文不乱码
csv_file = open('trendiano_goods_info.csv', 'w', newline = '', encoding = 'utf-8-sig')
csv_writer = csv.writer(csv_file)
## 命名字段
csv_writer.writerow(['cat1_name', 'cat2_name', 'goods_name', 'skc_id', 
                     'sale_price', 'origin_price','href', 'style', 
                     'material', 'length', 'stereotype', 'img_src'])
for row_num in range(cat_list.shape[0]):
    for page_num in range(cat_list.page_num[row_num]):
        # 二级类目商品列表页面中的商品主信息
        ## 页面
        s1 = requests.Session()
        s1.keep_alive = False
        url1 = base_url + cat_list.cat2_href[row_num] + url_end1 + str(page_num + 1) + url_end2
        page1 = s1.get(url1, headers = header)
        source1 = BeautifulSoup(page1.content, 'html.parser', from_encoding = 'gb18030')
        ## 商品主信息
        goods_infos = source1.find_all('div', class_ = 'chip')
        for goods_info in goods_infos:
            goods_name = goods_info.find('span', class_ = 'chip_name').string.replace('\n',"")
            skc_id = goods_info.find('a').get('data-sku').replace('\n',"")
            sale_price = goods_info.find('p', class_ = 'chip_price').span.string.replace('\n',"")
            try:
                origin_price = goods_info.find('p', class_ = 'chip_price').find('del').string
            except Exception as e:
                origin_price = None
            href = goods_info.find('a').get('href')
            # 商品详情页面中的商品辅信息和图片
            ## 页面
            s2 = requests.session()
            s2.keep_alive = False
            url2 = base_url + href
            page2 = s2.get(url2, headers = header)
            source2 = BeautifulSoup(page2.content, 'html.parser', from_encoding = 'gb18030')
            ## 商品信息
            goods_info2 = source2.find('dl', class_ = 'pro_description').find_all('dl')
            style = goods_info2[1].dd.string.replace('\n',"")
            try:
                material = goods_info2[3].dd.string.replace('\n',"")
            except Exception as e:
                material = None
            try:
                length = goods_info2[4].dd.string.replace('\n',"")
            except Exception as e:
                length = None
            try:
                stereotype = goods_info2[5].dd.string.replace('\n',"")
            except Exception as e:
                stereotype = None  
            img_src = source2.find('div', class_ = 'product_img_show').find('img').get('src')
            ## 把商品信息写入到 csv 文件中
            csv_writer.writerow([cat_list.cat1_name[row_num], cat_list.cat2_name[row_num], 
                                 goods_name, skc_id, sale_price, origin_price, href,
                                 style, material, length, stereotype, img_src])
            '''
            ## 保存商品主图到本地文件夹
            img = requests.get(img_src, timeout = 3)
            img_name = "trendiano_goods_img/"+ skc_id + ".jpg"
            fp = open(img_name, 'wb')
            fp.write(img.content)
            fp.close()
            ''' 
            '''
            ## 显示单个商品进度
            print(cat_list.cat1_name[row_num], cat_list.cat2_name[row_num], '第', page_num+1, '页')
            print(skc_id)
            print('------------')
            ''' 
        ## 显示进度
        print(cat_list.cat1_name[row_num], cat_list.cat2_name[row_num], '第', page_num+1, '页')
        print('############')
        ## 每翻一页，休息一下 
        time.sleep(10)
    ## 每爬取一个品类，休息一下
    time.sleep(30)
## 关闭csv文件
csv_file.close()

print('结束')
# Out:
# 开始
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3011170923
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3343840781
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3346810090
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3011170781
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3011170782
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GE3012280090
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GI3015160510
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3010110010
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GE3016070120
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3010980090
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3010980530
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3010160090
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3010090190
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3013850971
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3010090000
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3010380010
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3010380090
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3010380520
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3010850910
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3012220000
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC3012220090
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GE2011950090
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GI2014650090
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GE2010240000
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GE2010240090
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GE2010240601
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GE2010800090
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GE2010940090
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GI2014010000
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# 3GC1011160000
# ------------
# T恤/衬衫 长袖衬衫 第 1 页
# ############
# T恤/衬衫 长袖衬衫 第 2 页
# 3GI1015630943
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GI1015630955
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1017070000
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1017070090
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1010500090
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1010500530
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC101397P000
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC101397P090
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GI1016300000
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GI1016300090
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1016870000
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1016870090
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GE1016940000
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GE1016940090
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1010190782
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1010190784
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1011140000
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1011140090
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GI1015900090
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1017410000
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1017410090
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GC1013930783
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# 3GI1016570920
# ------------
# T恤/衬衫 长袖衬衫 第 2 页
# ############
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC3016370000
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC3016370090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GE2012920090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GI2014840090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC2016290090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GE2010080090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GE2012920000
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC2011550000
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC2011550090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC2011550120
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GI2014510090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC2011470520
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC2011470090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC2013000995
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC2015580090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GE2011620030
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GI2014490410
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GI2014490510
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GI2014110910
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GI2014230000
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GI2014430090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GI2014230090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC1011150000
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC1013450090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GC1013450530
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GE1013460000
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# 3GE1013460090
# ------------
# T恤/衬衫 短袖衬衫 第 1 页
# ############

# %%
# ####################
# 爬取最近两个月上市的新品
# ####################

newin_url = ['New_in/New_in_9_20/','New_in/New_in_9_6/']
newin_date = ['2018-9-20', '2018-9-6']
newin_page = [3, 2]
# 打开 csv 文件，encoding = 'utf-8-sig'，保证写入中文不乱码
csv_file = open('trendiano_goods_newin.csv', 'w', newline = '', encoding = 'utf-8-sig')
csv_writer = csv.writer(csv_file)
## 命名字段
csv_writer.writerow(['skc_id', 'newin_date'])
for row_num in range(len(newin_date)):
    for page_num in range(newin_page[row_num]):
        # 新品skc-id
        url1 = base_url + newin_url[row_num] + url_end1 + str(page_num + 1) + url_end3
        page1 = requests.get(url1, headers = header)
        source1 = BeautifulSoup(page1.content, 'html.parser', from_encoding = 'gb18030')
        goods_infos = source1.find_all('div', class_ = 'chip')
        for goods_info in goods_infos:
            skc_id = goods_info.find('a').get('data-sku').replace('\n',"")
            ## 把商品信息写入到 csv 文件中
            csv_writer.writerow([skc_id, newin_date[row_num]])
    # 每翻一页，休息一下，5秒钟 
    time.sleep(5)
## 关闭csv文件
csv_file.close()

# %%
###################
# 以下是单独爬取的脚本
###################

url1 = base_url + cat_list.cat2_href[1] + url_end1 + str(1) + url_end2
page1 = requests.get(url1)
source1 = BeautifulSoup(page1.content, 'html.parser', from_encoding = 'gb18030')
# 商品信息
goods_infos = source1.find_all('div', class_ = 'chip')
for goods_info in goods_infos:
    goods_name = goods_info.find('span', class_ = 'chip_name').string.replace('\n',"")
    skc_id = goods_info.find('a').get('data-sku').replace('\n',"")
    sale_price = goods_info.find('p', class_ = 'chip_price').span.string.replace('\n',"")
    try:
        origin_price = goods_info.find('p', class_ = 'chip_price').find('del').string
    except Exception as e:
        origin_price = sale_price
    href = goods_info.find('a').get('href')
    # 商品详情页面中的商品辅信息和图片
    ## 页面
    url2 = base_url + href
    page2 = requests.get(url2)
    source2 = BeautifulSoup(page2.content, 'html.parser', from_encoding = 'gb18030')
    ## 商品信息
    goods_info2 = source2.find('dl', class_ = 'pro_description').find_all('dl')
    style = goods_info2[1].dd.string.replace('\n',"")
    material = goods_info2[3].dd.string.replace('\n',"")
    length = goods_info2[4].dd.string.replace('\n',"")
    stereotype = goods_info2[5].dd.string.replace('\n',"")
    img_src = source2.find('div', class_ = 'product_img_show').find('img').get('src')
    print(goods_name)
    print(skc_id)
    print(sale_price)
    print(origin_price)
    print(href)
    print(style)
    print(material)
    print(length)
    print(stereotype)
    print('----')
# Out:
# 棉质宽松印花圆领T恤
# 3GC3025810090
# ￥499
# None
# /p/3GC3025810090.shtml
# 模仿粉笔黑白涂鸦风格，Colourful字母印花以贴布绣形式不对称饰于前幅，个性中展现年轻活力气息；圆领短袖轮廓，配合宽松版型设计，呼应休闲随性基调；甄选棉质面料打造，亲肤柔软透气，穿着舒适自在；时髦休闲单品，下装配入短裤或束脚哈伦裤，加入低帮鞋，轻松打造阳光帅气潮男形象
# 面料:棉96.0% 氨纶4.0%印花贴布:棉100%
# 适中
# 宽松
# ----
# 纯棉纯色中长宽松T恤
# 3GC3025880000
# ￥399
# None
# /p/3GC3025880000.shtml
# 静默淡然的纯色衣身，传递出宁静质朴的现代生活审美，勾勒雅致素净质感；双肩同色贴布绣装饰，赋予衣服更多时尚看点，低调中展现个性；中长款长度剪裁，配合流畅线条宽松版型，构筑悠闲舒适廓形；甄选亲肤质感纯棉面料，柔软透气吸汗，穿着舒适自在；时髦休闲款式，下装配入短裤或束脚哈伦裤，加入低帮鞋，轻松打造阳光帅气潮男形象
# 面料:棉100%撞料:锦纶100%
# 中长
# 宽松
# ----
# 纯棉纯色中长宽松T恤
# 3GC3025880090
# ￥399
# None
# /p/3GC3025880090.shtml
# 静默淡然的纯色衣身，传递出宁静质朴的现代生活审美，勾勒雅致素净质感；双肩同色贴布绣装饰，赋予衣服更多时尚看点，低调中展现个性；中长款长度剪裁，配合流畅线条宽松版型，构筑悠闲舒适廓形；甄选亲肤质感纯棉面料，柔软透气吸汗，穿着舒适自在；时髦休闲款式，下装配入短裤或束脚哈伦裤，加入低帮鞋，轻松打造阳光帅气潮男形象
# 面料:棉100%撞料:锦纶100%
# 中长
# 宽松
# ----
# 纯棉刺绣圆领短袖T恤
# 3GC3026400000
# ￥499
# None
# /p/3GC3026400000.shtml
# 运用精巧细致的刺绣工艺，勾画乖张眼睛图案，透着宗教神秘色彩，搭配英文Slogan印花与花蛇图案，亮点出挑个性吸睛；圆领短袖轮廓，线条处理利落称身，呼应休闲基调；甄选亲肤质感纯棉面料，柔软透气吸汗，穿着舒适自在；时髦休闲款式，下装配入短裤或束脚哈伦裤，加入低帮鞋，轻松打造阳光帅气潮男形象
# 面料:棉100%里布:聚酯纤维100%
# 适中
# 合体
# ----
# 纯棉刺绣圆领短袖T恤
# 3GC3026400090
# ￥499
# None
# /p/3GC3026400090.shtml
# 运用精巧细致的刺绣工艺，勾画乖张眼睛图案，透着宗教神秘色彩，搭配英文Slogan印花与花蛇图案，亮点出挑个性吸睛；圆领短袖轮廓，线条处理利落称身，呼应休闲基调；甄选亲肤质感纯棉面料，柔软透气吸汗，穿着舒适自在；时髦休闲款式，下装配入短裤或束脚哈伦裤，加入低帮鞋，轻松打造阳光帅气潮男形象
# 面料:棉100%里布:聚酯纤维100%
# 适中
# 合体
# ----
# 纯棉刺绣圆领短袖T恤
# 3GC3026400181
# ￥499
# None
# /p/3GC3026400181.shtml
# 运用精巧细致的刺绣工艺，勾画乖张眼睛图案，透着宗教神秘色彩，搭配英文Slogan印花与花蛇图案，亮点出挑个性吸睛；圆领短袖轮廓，线条处理利落称身，呼应休闲基调；甄选亲肤质感纯棉面料，柔软透气吸汗，穿着舒适自在；时髦休闲款式，下装配入短裤或束脚哈伦裤，加入低帮鞋，轻松打造阳光帅气潮男形象
# 面料:棉100%里布:聚酯纤维100%
# 适中
# 合体
# ----
# 纯棉刺绣字母虎头T恤
# 3GC3026420000
# ￥499
# None
# /p/3GC3026420000.shtml
# 拥有凹凸立体感的英文Slogan，以Colourful撞色配合刺绣工艺呈现，瞬间虏获视线；运用精巧细致的刺绣工艺，勾画威风凌凌虎头图案，于胸前成为点睛亮点，个性出挑；圆领短袖轮廓，线条处理利落称身，呼应休闲基调；甄选亲肤质感纯棉面料，柔软透气吸汗，穿着舒适自在；时髦休闲款式，下装配入短裤或束脚哈伦裤，加入低帮鞋，轻松打造阳光帅气潮男形象
# 面料:棉100%(绣花线除外)前幅网里:聚酯纤维100%
# 适中
# 合体
# ----
# 纯棉刺绣字母虎头T恤
# 3GC3026420090
# ￥499
# None
# /p/3GC3026420090.shtml
# 拥有凹凸立体感的英文Slogan，以Colourful撞色配合刺绣工艺呈现，瞬间虏获视线；运用精巧细致的刺绣工艺，勾画威风凌凌虎头图案，于胸前成为点睛亮点，个性出挑；圆领短袖轮廓，线条处理利落称身，呼应休闲基调；甄选亲肤质感纯棉面料，柔软透气吸汗，穿着舒适自在；时髦休闲款式，下装配入短裤或束脚哈伦裤，加入低帮鞋，轻松打造阳光帅气潮男形象
# 面料:棉100%(绣花线除外)前幅网里:聚酯纤维100%
# 适中
# 合体
# ----
# 纯棉刺绣字母虎头T恤
# 3GC3026420600
# ￥499
# None
# /p/3GC3026420600.shtml
# 拥有凹凸立体感的英文Slogan，以Colourful撞色配合刺绣工艺呈现，瞬间虏获视线；运用精巧细致的刺绣工艺，勾画威风凌凌虎头图案，于胸前成为点睛亮点，个性出挑；圆领短袖轮廓，线条处理利落称身，呼应休闲基调；甄选亲肤质感纯棉面料，柔软透气吸汗，穿着舒适自在；时髦休闲款式，下装配入短裤或束脚哈伦裤，加入低帮鞋，轻松打造阳光帅气潮男形象
# 面料:棉100%(绣花线除外)前幅网里:聚酯纤维100%
# 适中
# 合体
# ----
# 短袖圆领t恤宽松撞色
# 3GI3025610510
# ￥699
# None
# /p/3GI3025610510.shtml
# 大片亮色渐变晕染色块，带来醒目新鲜视觉效果，洋溢摩登波普风艺术气息；玩味廓形艺术，落肩oversize轮廓设计，带来轻松时髦气息，潮流感升级；甄选优质面料打造，柔软顺滑，贴身穿着舒适自在；本身足够抢眼，与简约风下装简单搭配即可时尚出挑，潮人不容错过；与束脚九分裤、运动鞋、斜挎小包混搭，刻画潮帅前卫印象
# 面料:聚酯纤维90.6% 氨纶9.4%罗纹:聚酯纤维95.1% 氨纶4.9%
# 适中
# 宽松
# ----
# 短袖圆领t恤宽松撞色
# 3GI3025610600
# ￥699
# None
# /p/3GI3025610600.shtml
# 大片亮色渐变晕染色块，带来醒目新鲜视觉效果，洋溢摩登波普风艺术气息；玩味廓形艺术，落肩oversize轮廓设计，带来轻松时髦气息，潮流感升级；甄选优质面料打造，柔软顺滑，贴身穿着舒适自在；本身足够抢眼，与简约风下装简单搭配即可时尚出挑，潮人不容错过；与束脚九分裤、运动鞋、斜挎小包混搭，刻画潮帅前卫印象
# 面料:聚酯纤维90.6% 氨纶9.4%罗纹:聚酯纤维95.1% 氨纶4.9%
# 适中
# 宽松
# ----
# 拼接中长宽松短袖T恤
# 3GI3025630000
# ￥599
# None
# /p/3GI3025630000.shtml
# 双层拼接手法，将个性印花图案半隐于网布之下，丰富图案层次，更添摩登新魅；玩味廓形艺术，落肩oversize轮廓设计，带来轻松时髦气息，潮流感升级；中长衣长设计，提升休闲率性味道，更具时尚型格；与深色百慕大短裤、中筒袜、运动鞋混搭，活力造型尽显青春帅气
# 面料1:聚酯纤维100%面料2:聚酯纤维93.5% 氨纶6.5%罗纹:聚酯纤维89.8% 棉5.9% 氨纶4.3%
# 中长
# 宽松
# ----
# 拼接中长宽松短袖T恤
# 3GI3025630090
# ￥599
# None
# /p/3GI3025630090.shtml
# 双层拼接手法，将个性印花图案半隐于网布之下，丰富图案层次，更添摩登新魅；玩味廓形艺术，落肩oversize轮廓设计，带来轻松时髦气息，潮流感升级；中长衣长设计，提升休闲率性味道，更具时尚型格；与深色百慕大短裤、中筒袜、运动鞋混搭，活力造型尽显青春帅气
# 面料1:聚酯纤维100%面料2:聚酯纤维93.5% 氨纶6.5%罗纹:聚酯纤维89.8% 棉5.9% 氨纶4.3%
# 中长
# 宽松
# ----
# 人像字母宽松短袖t恤
# 3GI3025640090
# ￥699
# None
# /p/3GI3025640090.shtml
# 糅合刺绣和印花手法呈现字母及人像，丰富的图案层次感赋予休闲衣衫更多潮流解读，摩登显个性；玩味廓形艺术，落肩oversize轮廓设计，带来轻松时髦气息，范儿升级；面料柔软细腻，贴身穿着舒适无负担；配以直筒运动裤、运动鞋，刻画活力阳光潮人印象；单穿或内搭皆适宜，值得入手
# 面料:粘纤63.0% 锦纶32.3% 氨纶4.7%(绣花线除外)网里:聚酯纤维100%罗纹:锦纶100%
# 适中
# 宽松
# ----
# 人像字母宽松短袖t恤
# 3GI3025640600
# ￥699
# None
# /p/3GI3025640600.shtml
# 糅合刺绣和印花手法呈现字母及人像，丰富的图案层次感赋予休闲衣衫更多潮流解读，摩登显个性；玩味廓形艺术，落肩oversize轮廓设计，带来轻松时髦气息，范儿升级；面料柔软细腻，贴身穿着舒适无负担；配以直筒运动裤、运动鞋，刻画活力阳光潮人印象；单穿或内搭皆适宜，值得入手
# 面料:粘纤63.0% 锦纶32.3% 氨纶4.7%(绣花线除外)网里:聚酯纤维100%罗纹:锦纶100%
# 适中
# 宽松
# ----
# 纯棉纯色中长宽松T恤
# 3GC3023940000
# ￥499
# None
# /p/3GC3023940000.shtml
# 静默淡然的纯色衣身，传递出宁静质朴的现代生活审美，勾勒雅致素净质感；前幅大口袋装饰，以同色构筑更能突出设计感，个性低调；中长款长度剪裁，配合流畅线条宽松版型，构筑悠闲舒适廓形；甄选亲肤质感纯棉面料，柔软透气吸汗，穿着舒适自在；时髦休闲款式，下装配入各式运动休闲风长裤，加入低帮鞋，打造闲适Daily风
# 面料:棉100%撞料:锦纶100%
# 中长
# 宽松
# ----
# 纯棉纯色中长宽松T恤
# 3GC3023940090
# ￥499
# None
# /p/3GC3023940090.shtml
# 静默淡然的纯色衣身，传递出宁静质朴的现代生活审美，勾勒雅致素净质感；前幅大口袋装饰，以同色构筑更能突出设计感，个性低调；中长款长度剪裁，配合流畅线条宽松版型，构筑悠闲舒适廓形；甄选亲肤质感纯棉面料，柔软透气吸汗，穿着舒适自在；时髦休闲款式，下装配入各式运动休闲风长裤，加入低帮鞋，打造闲适Daily风
# 面料:棉100%撞料:锦纶100%
# 中长
# 宽松
# ----
# 短袖t恤钉珠字母纯棉
# 3GC2026480000
# ￥599
# None
# /p/3GC2026480000.shtml
# 利用钉珠手法串成字母图案，以立体装饰效果传递出个性时尚魅力，吸睛度升级；基础圆领恤衫，廓形剪裁利落干净，定格实穿特性；甄选纯棉面料，贴身穿着舒适亲肤透气；字母t恤，与各式裤装皆可轻松混搭；与运动风短裤、低帮鞋相配，活力帅气
# 面料:棉100%
# 适中
# 合体
# ----
# 短袖t恤钉珠字母纯棉
# 3GC2026480090
# ￥599
# None
# /p/3GC2026480090.shtml
# 利用钉珠手法串成字母图案，以立体装饰效果传递出个性时尚魅力，吸睛度升级；基础圆领恤衫，廓形剪裁利落干净，定格实穿特性；甄选纯棉面料，贴身穿着舒适亲肤透气；字母t恤，与各式裤装皆可轻松混搭；与运动风短裤、低帮鞋相配，活力帅气
# 面料:棉100%
# 适中
# 合体
# ----
# 狗狗刺绣棉质短袖t恤
# 3GC2026500000
# ￥599
# None
# /p/3GC2026500000.shtml
# 前幅狗狗图案，利用线绣及钉珠工艺呈现，以立体肌理感轻松传递出萌趣活力之感，分外吸睛；整体廓形设计简洁大气，线条剪裁毫无累赘，定格百搭实穿特性；主面料为纯棉，拥有柔软手感及良好透气吸湿性，贴身穿着亦舒适亲肤；出挑图案单品，与任意下装混搭皆可，值得入手；与运动风九分裤、运动鞋搭配，活力帅气，青春洋溢；亦可与百慕大短裤、低帮鞋、斜挎小包相配，一身造型见到斯文，又不失去时髦活力之范
# 面料:棉100%绣线1:粘纤100%绣线2:聚酯纤维100%(装饰亮片及连接线除外)
# 适中
# 合体
# ----
# 狗狗刺绣棉质短袖t恤
# 3GC2026500090
# ￥599
# None
# /p/3GC2026500090.shtml
# 前幅狗狗图案，利用线绣及钉珠工艺呈现，以立体肌理感轻松传递出萌趣活力之感，分外吸睛；整体廓形设计简洁大气，线条剪裁毫无累赘，定格百搭实穿特性；主面料为纯棉，拥有柔软手感及良好透气吸湿性，贴身穿着亦舒适亲肤；出挑图案单品，与任意下装混搭皆可，值得入手；与运动风九分裤、运动鞋搭配，活力帅气，青春洋溢；亦可与百慕大短裤、低帮鞋、斜挎小包相配，一身造型见到斯文，又不失去时髦活力之范
# 面料:棉100%绣线1:粘纤100%绣线2:聚酯纤维100%(装饰亮片及连接线除外)
# 适中
# 合体
# ----
# 狗狗刺绣棉质短袖t恤
# 3GC2026500730
# ￥599
# None
# /p/3GC2026500730.shtml
# 前幅狗狗图案，利用线绣及钉珠工艺呈现，以立体肌理感轻松传递出萌趣活力之感，分外吸睛；整体廓形设计简洁大气，线条剪裁毫无累赘，定格百搭实穿特性；主面料为纯棉，拥有柔软手感及良好透气吸湿性，贴身穿着亦舒适亲肤；出挑图案单品，与任意下装混搭皆可，值得入手；与运动风九分裤、运动鞋搭配，活力帅气，青春洋溢；亦可与百慕大短裤、低帮鞋、斜挎小包相配，一身造型见到斯文，又不失去时髦活力之范
# 面料:棉100%绣线1:粘纤100%绣线2:聚酯纤维100%(装饰亮片及连接线除外)
# 适中
# 合体
# ----
# 字母印花龙短袖T恤男
# 3GC2026510000
# ￥499
# None
# /p/3GC2026510000.shtml
# 运用钉珠及印花方式呈现字母和龙图案，形成丰富层次感，成为本款焦点所在，个性出挑；基础圆领恤衫，廓形剪裁利落干净，定格实穿特性；甄选纯棉面料，贴身穿着舒适亲肤透气；时尚又百搭，与任意下装搭配皆适宜，值得入手；碰撞短裤、低帮鞋，简单造型却透着青春活力之感
# 面料:棉100%里布:聚酯纤维100%
# 适中
# 合体
# ----
# 字母印花龙短袖T恤男
# 3GC2026510090
# ￥499
# None
# /p/3GC2026510090.shtml
# 运用钉珠及印花方式呈现字母和龙图案，形成丰富层次感，成为本款焦点所在，个性出挑；基础圆领恤衫，廓形剪裁利落干净，定格实穿特性；甄选纯棉面料，贴身穿着舒适亲肤透气；时尚又百搭，与任意下装搭配皆适宜，值得入手；碰撞短裤、低帮鞋，简单造型却透着青春活力之感
# 面料:棉100%里布:聚酯纤维100%
# 适中
# 合体
# ----
# 字母印花龙短袖T恤男
# 3GC2026510730
# ￥499
# None
# /p/3GC2026510730.shtml
# 运用钉珠及印花方式呈现字母和龙图案，形成丰富层次感，成为本款焦点所在，个性出挑；基础圆领恤衫，廓形剪裁利落干净，定格实穿特性；甄选纯棉面料，贴身穿着舒适亲肤透气；时尚又百搭，与任意下装搭配皆适宜，值得入手；碰撞短裤、低帮鞋，简单造型却透着青春活力之感
# 面料:棉100%里布:聚酯纤维100%
# 适中
# 合体
# ----
# 纯棉宽松圆领短袖T恤
# 3GC2025940000
# ￥499
# None
# /p/3GC2025940000.shtml
# 创意不规则衣摆设计，以一条印有“TRE”的字母织带从侧面连接前后幅，瞬间注入街头不羁活力气息，个性有范；以精致罗纹构筑圆领，配合宽松版型Cutting，尽显潇洒随性；甄选亲肤质感纯棉面料，柔韧细致，透气吸汗穿着舒适；时髦休闲上装，可配入亮色调下装点亮层次，或与束脚哈伦裤或短裤搭配，加入运动鞋，打造帅气型格造型
# 面料:棉100%撞料:棉100%
# 适中
# 宽松
# ----
# 纯棉宽松圆领短袖T恤
# 3GC2025940090
# ￥499
# None
# /p/3GC2025940090.shtml
# 创意不规则衣摆设计，以一条印有“TRE”的字母织带从侧面连接前后幅，瞬间注入街头不羁活力气息，个性有范；以精致罗纹构筑圆领，配合宽松版型Cutting，尽显潇洒随性；甄选亲肤质感纯棉面料，柔韧细致，透气吸汗穿着舒适；时髦休闲上装，可配入亮色调下装点亮层次，或与束脚哈伦裤或短裤搭配，加入运动鞋，打造帅气型格造型
# 面料:棉100%撞料:棉100%
# 适中
# 宽松
# ----
# 纯棉宽松印花短袖T恤
# 3GC2026300000
# ￥499
# None
# /p/3GC2026300000.shtml
# Logo装饰一贯是时尚设计者钟爱元素，秉承其耐看长青的性质，深受大众追捧；仅以一英文词组Logo轻轻点缀胸前，看似毫无波澜却经典时尚；有别于前幅低调典雅，后幅大面积街景Mix人像抽象印花，霓虹灯图像的加入大幅度强化了街头风味儿；运用黑白色调渲染，使原本纷繁多彩印花被抑制，恍若把兴奋与喧嚣热闹强制压抑下来，让人心思百转耐人寻味；以精致罗纹构筑圆领，配合宽松版型Cutting，尽显潇洒随性；甄选亲肤质感纯棉面料，柔韧细致，透气吸汗穿着舒适；充满亮点休闲单品，下装搭配纯色休闲裤，加入低帮鞋，打造别样吸睛范儿
# 面料:棉100%
# 适中
# 宽松
# ----
# 纯棉宽松印花短袖T恤
# 3GC2026300090
# ￥499
# None
# /p/3GC2026300090.shtml
# Logo装饰一贯是时尚设计者钟爱元素，秉承其耐看长青的性质，深受大众追捧；仅以一英文词组Logo轻轻点缀胸前，看似毫无波澜却经典时尚；有别于前幅低调典雅，后幅大面积街景Mix人像抽象印花，霓虹灯图像的加入大幅度强化了街头风味儿；运用黑白色调渲染，使原本纷繁多彩印花被抑制，恍若把兴奋与喧嚣热闹强制压抑下来，让人心思百转耐人寻味；以精致罗纹构筑圆领，配合宽松版型Cutting，尽显潇洒随性；甄选亲肤质感纯棉面料，柔韧细致，透气吸汗穿着舒适；充满亮点休闲单品，下装搭配纯色休闲裤，加入低帮鞋，打造别样吸睛范儿
# 面料:棉100%
# 适中
# 宽松
# ----
# 纯棉宽松印花短袖T恤
# 3GC2026300410
# ￥499
# None
# /p/3GC2026300410.shtml
# Logo装饰一贯是时尚设计者钟爱元素，秉承其耐看长青的性质，深受大众追捧；仅以一英文词组Logo轻轻点缀胸前，看似毫无波澜却经典时尚；有别于前幅低调典雅，后幅大面积街景Mix人像抽象印花，霓虹灯图像的加入大幅度强化了街头风味儿；运用黑白色调渲染，使原本纷繁多彩印花被抑制，恍若把兴奋与喧嚣热闹强制压抑下来，让人心思百转耐人寻味；以精致罗纹构筑圆领，配合宽松版型Cutting，尽显潇洒随性；甄选亲肤质感纯棉面料，柔韧细致，透气吸汗穿着舒适；充满亮点休闲单品，下装搭配纯色休闲裤，加入低帮鞋，打造别样吸睛范儿
# 面料:棉100%
# 适中
# 宽松
# ----

# %%
## 保存商品主图到本地文件夹
img = requests.get(img_src, timeout = 5)
img_name = "trendiano_goods_img/"+ skc_id + ".jpg"
fp = open(img_name, 'wb')
fp.write(img.content)
fp.close()
# Out:
# http://img1.ochirly.com.cn/wcsstore/TrendyCatalogAssetStore/images/trendy/trendiano/2018/b/3GC2025920000/3GC2025920000_m_1.jpg
# trendiano_goods_img/3GC2025920000.jpg

# %%
## 单个商品的主信息
url1 = 'http://www.trendiano.com/T_shirts/Long_sleeved_shirts/list-2-30-listedDate%20desc-0-0-0-0-0.shtml'
page1 = requests.get(url1, headers = header)
source1 = BeautifulSoup(page1.content, 'html.parser', from_encoding = 'gb18030')
goods_info = source1.find('div', class_ = 'chip')
goods_name = goods_info.find('span', class_ = 'chip_name').string.replace('\n',"")
skc_id = goods_info.find('a').get('data-sku').replace('\n',"")
sale_price = goods_info.find('p', class_ = 'chip_price').span.string.replace('\n',"")
try:
    origin_price = goods_info.find('p', class_ = 'chip_price').find('del').string
except Exception as e:
    origin_price = None
href = goods_info.find('a').get('href')
print(goods_name)
print(skc_id)
print(sale_price)
print(origin_price)
print(href)
# Out:
# 宽松纯棉格子长袖衬衫
# 3GI1015630955
# ￥489
# ￥699
# /p/3GI1015630955.shtml

# %%
# 商品详情页面中的商品辅信息和图片
## 页面
url2 = 'http://www.trendiano.com/p/3GI1015630955.shtml'
page2 = requests.get(url2, headers = header)
source2 = BeautifulSoup(page2.content, 'html.parser', from_encoding = 'gb18030')
## 商品辅信息
goods_info2 = source2.find('dl', class_ = 'pro_description').find_all('dl')
style = goods_info2[1].dd.string.replace('\n',"")
material = goods_info2[3].dd.string.replace('\n',"")
length = goods_info2[4].dd.string.replace('\n',"")
stereotype = goods_info2[5].dd.string.replace('\n',"")
img_src = source2.find('div', class_ = 'product_img_show').find('img').get('src')
print(goods_name)
print(skc_id)
print(sale_price)
print(origin_price)
print(href)
print(style)
print(material)
print(length)
print(stereotype)
print(img_src)
# Out:
# 宽松纯棉格子长袖衬衫
# 3GI1015630955
# ￥489
# ￥699
# /p/3GI1015630955.shtml
# 细格子元素的加入，赋予衣衫清新干净气质，尤显帅气文雅；个性化slogan成功吸睛抢眼，以精致刺绣手法呈现，更显时尚别致；弧形衣摆剪裁，添注轻松休闲味道，一改正式通勤传统；宽松版型，巧妙修饰及包容身材，舒适度提升；精选纯棉面料打造，穿着舒适自在透气；可单穿可作为外套亦可内搭，可塑性强，值得入手；混搭套头衫，下装配以合体长裤、板鞋，并加入斜挎小包，通身造型干净青春，释放时髦活力之感
# 面料:棉100%(绣花线除外)
# 长款
# 宽松
# http://img1.ochirly.com.cn/wcsstore/TrendyCatalogAssetStore/images/trendy/trendiano/2018/a/3GI1015630955/3GI1015630955_m_1.jpg

# %%
## 所有 URL
cat1_url = source.find('div', class_ = "nav2013_ul_box").ul.find_all('li')
for item in cat1_url:
    cat1_href = item.find_all('a')
    for a in cat1_href:
        print(a.get('href'))
# Out:
# /index.shtml
# /a/news/active/list.shtml
# /a/news/new_in/list.shtml
# /sale/list.shtml
# /sale/T_shirts/list.shtml
# /sale/Shirts/list.shtml
# /sale/Pants/list.shtml
# /sale/Hoodies/list.shtml
# /sale/Coats/list.shtml
# /sale/Accessories/list.shtml
# /New_in/list.shtml
# /New_in/New_in_8_16/list.shtml
# /New_in/New_in_8_2/list.shtml
# /New_in/New_in_7_19/list.shtml
# /New_in/New_in_7_5/list.shtml
# /New_in/New_in_2018SS/list.shtml
# /New_in/All_new_products/list.shtml
# /THREE_MAJOR_LABELS/list.shtml
# /THREE_MAJOR_LABELS/Golden_Labels/list.shtml
# /THREE_MAJOR_LABELS/Black_Labels/list.shtml
# /THREE_MAJOR_LABELS/White_Labels/list.shtml
# /T_shirts/list.shtml
# /T_shirts/Sleeveless_T_shirts/list.shtml
# /T_shirts/Short_sleeved_T_shirts/list.shtml
# /T_shirts/Long_sleeved_T_shirts/list.shtml
# /T_shirts/POLO_shirts/list.shtml
# /Shirts/list.shtml
# /Shirts/Long_sleeved_shirts/list.shtml
# /Shirts/Short_sleeved_shirts/list.shtml
# /Shirts/Sleeveless_shirts/list.shtml
# /Pants/list.shtml
# /Pants/Casual_pants/list.shtml
# /Pants/Jeans/list.shtml
# /Coats/list.shtml
# /Coats/Hoodies/list.shtml
# /Coats/Woollen/list.shtml
# /Coats/Windbreakers/list.shtml
# /Coats/Jackets/list.shtml
# /Coats/Suits/list.shtml
# /Shoes/list.shtml
# /Shoes/Summer_shoes/list.shtml
# /Shoes/Casual_shoes/list.shtml
# /Accessories/list.shtml
# /Accessories/Hats/list.shtml
# /Accessories/Necklaces/list.shtml
# /Accessories/Bags/list.shtml
# /Accessories/Socks/list.shtml

# %%
# 获取一级类目的名称，strip()函数去除字符串的空格
for item in source.find('div', class_ = "nav2013_ul_box").ul.find_all('li'):
    cat_href = item.find_all('a')
    for a_str in cat_href:
        print(a_str.string.strip())
# Out:
# 首页
# 品牌动向
# 新品资讯
# 春夏大减价
# T恤/POLO衫
# 衬衫
# 裤装
# 卫衣
# 外套
# 配饰
# 全部新品
# 8月16号到店
# 8月2号到店
# 7月19号到店
# 7月5号到店
# 2018春夏合集
# 全部新品
# 三大系列
# 金标系列
# 黑标系列
# 白标系列
# T恤/POLO衫
# 无袖T恤
# 短袖T恤
# 长袖T恤
# POLO
# 衬衫
# 长袖衬衫
# 短袖衬衫
# 无袖衬衫
# 裤装
# 休闲裤
# 牛仔裤
# 薄外套
# 卫衣
# 毛织
# 风衣
# 夹克
# 西服
# 鞋
# 凉鞋/拖鞋
# 休闲鞋
# 配饰
# 帽
# 项链
# 包
# 袜
