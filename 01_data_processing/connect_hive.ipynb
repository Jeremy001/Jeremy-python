# %%
# 加载包
# %matplotlib inline
import sys
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pyhive import hive  
from TCLIService.ttypes import TOperationState

# %%
# 连接hive
conn = hive.connect(
	host='cloudera-edge-01.cdh01.cn-hangzhou.dianjia.io',
	port=10000,
	username="admin",
	database="default")
cursor = conn.cursor()

# %%
# 查询数据
cursor.execute("SELECT t1.* FROM dim_good_sku_base_info_dt AS t1 LIMIT 10", async=True)

# %%
# 取出数据结果
test_data = cursor.fetchall()
test_data

# %%
type(test_data)
# Out:
# list

# %%
# 数据类型是list，转换成Dataframe
test_data2 = pd.DataFrame(test_data)
test_data2
# Out:
#                    0                   1      2       3         4    5   6   \
# 0  367406505621725192  367401361228181504  10111  100351   女士珊瑚绒套装   玫红   S
# 1  367406505621725193  367402594500354050  10111  100351  女士舒绒印花睡袍   玫红   M
# 2  367407273296797698  367407273296797696  10111  100351  女士雪人夹棉套装   粉色   M
# 3  367440936818454528  367440918908772354  10140  100499        毛衣   黄色  00
# 4  367440936818454531  367440918908772356  10140  100499        外套  卡其色   S
# 5  367440936818454535  367440918908772353  10140  100499        毛衣   黄色  00
# 6  367440936818454547  367440918908772357  10140  100499        外套  卡其色   M
# 7  367568004961017857  367562970550509573  10091  100475     毛织连衣裙   红色   F
# 8  367568004961017861  367562970546315264  10091  100475      长袖毛衫   白色   F
# 9  367568004961017863  367562970550509576  10091  100475      长袖毛衫   宝蓝   F
#
#       7               8              9                   10  \
# 0  27800     C07302R3701    C07302R3701  407726873720655872
# 1  25800     C27188R3702    C27188R3702  407726873720655872
# 2  36800     C07308R8102    C07308R8102  407726876212072448
# 3  29900   1752722053200  1752722053200  407711085248909312
# 4  45900    17527220135S   17527220135S  407711085425070081
# 5  26900   1752722043200  1752722043200  407711085248909312
# 6  39900    17527220235M   17527220235M  407711085425070081
# 7  46800   M55331066R000  6908000052309  407711139527401472
# 8  39800   M55133069W000  6908000052415  407711140546617345
# 9  39800  ME55133069B070  6908000052477  407711129951805440
#
#                    11            12     13        14
# 0  284571117018963994   颜色：玫红  尺码：S      0  20180424
# 1  284571117018963979   颜色：玫红  尺码：M      0  20180424
# 2  284571117018963979   颜色：粉色  尺码：M      0  20180424
# 3  357679819460202497  颜色：黄色  尺码：00      0  20180424
# 4  357679819460202498  颜色：卡其色  尺码：S      0  20180424
# 5  357679819460202497  颜色：黄色  尺码：00      0  20180424
# 6  357679819460202499  颜色：卡其色  尺码：M      0  20180424
# 7  347988997047341066   颜色：红色  尺码：F  17784  20180424
# 8  347988997047341066   颜色：白色  尺码：F  15124  20180424
# 9  347988997047341066   颜色：宝蓝  尺码：F  15124  20180424

# %%
test_data
# Out:
# [(367406505621725192,
#   367401361228181504,
#   10111,
#   100351,
#   '女士珊瑚绒套装',
#   '玫红',
#   'S',
#   '27800',
#   'C07302R3701',
#   'C07302R3701',
#   407726873720655872,
#   284571117018963994,
#   '颜色：玫红  尺码：S',
#   0,
#   '20180424'),
#  (367406505621725193,
#   367402594500354050,
#   10111,
#   100351,
#   '女士舒绒印花睡袍',
#   '玫红',
#   'M',
#   '25800',
#   'C27188R3702',
#   'C27188R3702',
#   407726873720655872,
#   284571117018963979,
#   '颜色：玫红  尺码：M',
#   0,
#   '20180424'),
#  (367407273296797698,
#   367407273296797696,
#   10111,
#   100351,
#   '女士雪人夹棉套装',
#   '粉色',
#   'M',
#   '36800',
#   'C07308R8102',
#   'C07308R8102',
#   407726876212072448,
#   284571117018963979,
#   '颜色：粉色  尺码：M',
#   0,
#   '20180424'),
#  (367440936818454528,
#   367440918908772354,
#   10140,
#   100499,
#   '毛衣',
#   '黄色',
#   '00',
#   '29900',
#   '1752722053200',
#   '1752722053200',
#   407711085248909312,
#   357679819460202497,
#   '颜色：黄色  尺码：00',
#   0,
#   '20180424'),
#  (367440936818454531,
#   367440918908772356,
#   10140,
#   100499,
#   '外套',
#   '卡其色',
#   'S',
#   '45900',
#   '17527220135S',
#   '17527220135S',
#   407711085425070081,
#   357679819460202498,
#   '颜色：卡其色  尺码：S',
#   0,
#   '20180424'),
#  (367440936818454535,
#   367440918908772353,
#   10140,
#   100499,
#   '毛衣',
#   '黄色',
#   '00',
#   '26900',
#   '1752722043200',
#   '1752722043200',
#   407711085248909312,
#   357679819460202497,
#   '颜色：黄色  尺码：00',
#   0,
#   '20180424'),
#  (367440936818454547,
#   367440918908772357,
#   10140,
#   100499,
#   '外套',
#   '卡其色',
#   'M',
#   '39900',
#   '17527220235M',
#   '17527220235M',
#   407711085425070081,
#   357679819460202499,
#   '颜色：卡其色  尺码：M',
#   0,
#   '20180424'),
#  (367568004961017857,
#   367562970550509573,
#   10091,
#   100475,
#   '毛织连衣裙',
#   '红色',
#   'F',
#   '46800',
#   'M55331066R000',
#   '6908000052309',
#   407711139527401472,
#   347988997047341066,
#   '颜色：红色  尺码：F',
#   17784,
#   '20180424'),
#  (367568004961017861,
#   367562970546315264,
#   10091,
#   100475,
#   '长袖毛衫',
#   '白色',
#   'F',
#   '39800',
#   'M55133069W000',
#   '6908000052415',
#   407711140546617345,
#   347988997047341066,
#   '颜色：白色  尺码：F',
#   15124,
#   '20180424'),
#  (367568004961017863,
#   367562970550509576,
#   10091,
#   100475,
#   '长袖毛衫',
#   '宝蓝',
#   'F',
#   '39800',
#   'ME55133069B070',
#   '6908000052477',
#   407711129951805440,
#   347988997047341066,
#   '颜色：宝蓝  尺码：F',
#   15124,
#   '20180424')]

# %%
import pandas as pd
